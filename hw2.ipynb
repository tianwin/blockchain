# %% [markdown]
# ---
# title: "Homework 2"
# author: "Frank Dong"
# ---

# %% [markdown]
# # 1       Importing data and packages

# %%
# Import following packages
import pandas_datareader.data as pdr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import requests

# %% [markdown]
# # 2       Gather Coin token ID information from Coinmarket, Binance, or Coinbase.

# %% [markdown]
# ## 2.1        Getting Data From Binance

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

# %% [markdown]
# api_key = "fafad455-bb1d-4bac-8274-063bc5f17818"
#
#
# url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
# parameters = {
#   'start':'1',
#   'limit':'30',
#   'convert':'USD'
# }
# headers = {
#   'Accepts': 'application/json',
#   'X-CMC_PRO_API_KEY': api_key,
# }
#
# session = Session()
# session.headers.update(headers)
#
# try:
#   response = session.get(url, params=parameters)
#   data = json.loads(response.text)
#   print(data)
# except (ConnectionError, Timeout, TooManyRedirects) as e:
#   print(e)
# data["status"]
# len(data["data"])
# symbols = []
# ids = []
# closes = []
# names = []
# for i in range(len(data["data"])):
#     ids.append(data["data"][i]["id"])
#     closes.append(data["data"][i]["quote"]["USD"]["price"])
#     symbols.append(data["data"][i]["symbol"])
#     names.append(data["data"][i]["name"])
# df = pd.DataFrame({
#     "id": ids,
#     "symbol": symbols,
#     "name" : names,
#     "Coinname_closeprice": closes
# })
# df.head(10)

# %%
url = 'https://api.coingecko.com/api/v3/coins/markets'
parama = {
  'vs_currency': 'usd',
}

headers = {
  'Accepts': 'application/json',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parama)
  data = json.loads(response.text)
#   print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
df = pd.DataFrame(data[2:32], )

# %%
df.head()
# Out:
#              id symbol               name  \
# 0        tether   usdt             Tether
# 1   binancecoin    bnb                BNB
# 2        ripple    xrp                XRP
# 3      usd-coin   usdc               USDC
# 4  staked-ether  steth  Lido Staked Ether
#
#                                                image  current_price  \
# 0  https://assets.coingecko.com/coins/images/325/...       0.999223
# 1  https://assets.coingecko.com/coins/images/825/...     211.140000
# 2  https://assets.coingecko.com/coins/images/44/l...       0.499055
# 3  https://assets.coingecko.com/coins/images/6319...       0.999985
# 4  https://assets.coingecko.com/coins/images/1344...    1594.430000
#
#     market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0  83247743951                3             8.324774e+10   14920177093
# 1  32506721817                4             4.225599e+10     762056507
# 2  26625396639                5             4.994225e+10     685973201
# ...
